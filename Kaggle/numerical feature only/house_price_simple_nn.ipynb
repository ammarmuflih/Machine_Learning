# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error
# Out:
# 2025-05-17 02:01:49.388436: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
data_path = "/workspaces/Machine Learning/Kaggle/data/melb_data.csv"
data = pd.read_csv(data_path)
data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN        Yarra  -37.7996    144.9984  Northern Metropolitan
# 1     1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 2     1900.0        Yarra  -37.8093    144.9944  Northern Metropolitan
# 3        NaN        Yarra  -37.7969    144.9969  Northern Metropolitan
# 4     2014.0        Yarra  -37.8072    144.9941  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %%
data.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# std        0.691712      0.962634    3990.669241    541.014538    37.273762
# min        0.000000      0.000000       0.000000      0.000000  1196.000000
# 25%        1.000000      1.000000     177.000000     93.000000  1940.000000
# 50%        1.000000      2.000000     440.000000    126.000000  1970.000000
# 75%        2.000000      2.000000     651.000000    174.000000  1999.000000
# max        8.000000     10.000000  433014.000000  44515.000000  2018.000000
#
#           Lattitude    Longtitude  Propertycount
# count  13580.000000  13580.000000   13580.000000
# mean     -37.809203    144.995216    7454.417378
# std        0.079260      0.103916    4378.581772
# min      -38.182550    144.431810     249.000000
# 25%      -37.856822    144.929600    4380.000000
# 50%      -37.802355    145.000100    6555.000000
# 75%      -37.756400    145.058305   10331.000000
# max      -37.408530    145.526350   21650.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  float64
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12211 non-null  object
#  17  Lattitude      13580 non-null  float64
#  18  Longtitude     13580 non-null  float64
#  19  Regionname     13580 non-null  object
#  20  Propertycount  13580 non-null  float64
# dtypes: float64(12), int64(1), object(8)
# memory usage: 2.2+ MB

# %%
data.isna().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
# simple missing value handling
data = data.dropna(axis=0)
data.isna().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
numeric_cols = data.select_dtypes(include='number').columns.to_list()

# %%
y = data.Price
X = data[numeric_cols]
X = X.drop(columns=['Price'])

# %%
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)
scaler = StandardScaler()

train_X = scaler.fit_transform(train_X)
val_X = scaler.fit_transform(val_X)

train_y = np.log1p(train_y)
val_y = np.log1p(val_y)

# %%
model = models.Sequential([
    layers.Dense(6, activation='relu', input_shape=(train_X.shape[1],)),
    layers.Dense(8, activation='relu'),
    layers.Dense(8, activation='relu'),
    layers.Dense(8, activation='relu'),
    layers.Dense(1)  # output layer untuk regresi
])

model.compile(
    optimizer='adam',
    loss='mse',
    metrics='mae'
)
# Out:
# 2025-05-17 02:01:54.076101: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-05-17 02:01:54.099317: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-05-17 02:01:54.099617: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-05-17 02:01:54.100605: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-17 02:01:54.102900: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-05-17 02:01:54.103328: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-05-17 02:01:54.103628: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-05-17 02:01:56.118899: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-05-17 02:01:56.119983: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-05-17 02:01:56.120017: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1700] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2025-05-17 02:01:56.120732: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-05-17 02:01:56.121318: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5420 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
history = model.fit(train_X, train_y, validation_split=0.2, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 2025-05-17 02:01:59.486773: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2025-05-17 02:01:59.517799: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x435281c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-05-17 02:01:59.517853: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Ti, Compute Capability 8.6
# 2025-05-17 02:01:59.546417: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-05-17 02:01:59.853375: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 117/117 [==============================] - 5s 9ms/step - loss: 143.2260 - mae: 11.8144 - val_loss: 65.9940 - val_mae: 7.7505
# Epoch 2/50
# 117/117 [==============================] - 1s 7ms/step - loss: 25.2460 - mae: 4.0778 - val_loss: 11.4882 - val_mae: 2.7968
# Epoch 3/50
# 117/117 [==============================] - 1s 7ms/step - loss: 9.2805 - mae: 2.3983 - val_loss: 6.2224 - val_mae: 2.0116
# Epoch 4/50
# 117/117 [==============================] - 1s 7ms/step - loss: 5.3966 - mae: 1.7739 - val_loss: 3.8499 - val_mae: 1.5612
# Epoch 5/50
# 117/117 [==============================] - 1s 7ms/step - loss: 3.4836 - mae: 1.4009 - val_loss: 2.5412 - val_mae: 1.2610
# Epoch 6/50
# 117/117 [==============================] - 1s 7ms/step - loss: 2.3632 - mae: 1.1398 - val_loss: 1.7156 - val_mae: 1.0169
# Epoch 7/50
# 117/117 [==============================] - 1s 8ms/step - loss: 1.6364 - mae: 0.9420 - val_loss: 1.1816 - val_mae: 0.8391
# Epoch 8/50
# 117/117 [==============================] - 1s 8ms/step - loss: 1.1473 - mae: 0.7739 - val_loss: 0.8186 - val_mae: 0.6940
# Epoch 9/50
# 117/117 [==============================] - 1s 8ms/step - loss: 0.8187 - mae: 0.6504 - val_loss: 0.5795 - val_mae: 0.5833
# Epoch 10/50
# 117/117 [==============================] - 1s 8ms/step - loss: 0.5906 - mae: 0.5453 - val_loss: 0.4340 - val_mae: 0.5101
# Epoch 11/50
# 117/117 [==============================] - 1s 8ms/step - loss: 0.4446 - mae: 0.4698 - val_loss: 0.3206 - val_mae: 0.4332
# Epoch 12/50
# 117/117 [==============================] - 1s 7ms/step - loss: 0.3482 - mae: 0.4157 - val_loss: 0.2582 - val_mae: 0.3853
# Epoch 13/50
# 117/117 [==============================] - 1s 8ms/step - loss: 0.2800 - mae: 0.3753 - val_loss: 0.2134 - val_mae: 0.3532
# Epoch 14/50
# 117/117 [==============================] - 1s 8ms/step - loss: 0.2350 - mae: 0.3453 - val_loss: 0.1847 - val_mae: 0.3318
# Epoch 15/50
# 117/117 [==============================] - 1s 8ms/step - loss: 0.2033 - mae: 0.3249 - val_loss: 0.1668 - val_mae: 0.3174
# Epoch 16/50
# 117/117 [==============================] - 1s 7ms/step - loss: 0.1825 - mae: 0.3106 - val_loss: 0.1535 - val_mae: 0.3066
# Epoch 17/50
# 117/117 [==============================] - 1s 7ms/step - loss: 0.1670 - mae: 0.3002 - val_loss: 0.1448 - val_mae: 0.2974
# Epoch 18/50
# 117/117 [==============================] - 1s 8ms/step - loss: 0.1562 - mae: 0.2939 - val_loss: 0.1368 - val_mae: 0.2881
# Epoch 19/50
# 117/117 [==============================] - 1s 8ms/step - loss: 0.1477 - mae: 0.2869 - val_loss: 0.1363 - val_mae: 0.2872
# Epoch 20/50
# 117/117 [==============================] - 1s 8ms/step - loss: 0.1400 - mae: 0.2804 - val_loss: 0.1309 - val_mae: 0.2825
# Epoch 21/50
# 117/117 [==============================] - 1s 8ms/step - loss: 0.1356 - mae: 0.2778 - val_loss: 0.1243 - val_mae: 0.2743
# Epoch 22/50
# 117/117 [==============================] - 1s 8ms/step - loss: 0.1307 - mae: 0.2732 - val_loss: 0.1228 - val_mae: 0.2732
# Epoch 23/50
# 117/117 [==============================] - 1s 8ms/step - loss: 0.1273 - mae: 0.2704 - val_loss: 0.1269 - val_mae: 0.2793
# Epoch 24/50
# 117/117 [==============================] - 1s 8ms/step - loss: 0.1247 - mae: 0.2680 - val_loss: 0.1240 - val_mae: 0.2754
# Epoch 25/50
# 117/117 [==============================] - 1s 8ms/step - loss: 0.1218 - mae: 0.2649 - val_loss: 0.1193 - val_mae: 0.2677
# Epoch 26/50
# 117/117 [==============================] - 1s 8ms/step - loss: 0.1183 - mae: 0.2609 - val_loss: 0.1150 - val_mae: 0.2620
# Epoch 27/50
# 117/117 [==============================] - 1s 8ms/step - loss: 0.1164 - mae: 0.2597 - val_loss: 0.1123 - val_mae: 0.2613
# Epoch 28/50
# 117/117 [==============================] - 1s 8ms/step - loss: 0.1136 - mae: 0.2560 - val_loss: 0.1117 - val_mae: 0.2594
# Epoch 29/50
# 117/117 [==============================] - 1s 8ms/step - loss: 0.1133 - mae: 0.2558 - val_loss: 0.1302 - val_mae: 0.2807
# Epoch 30/50
# 117/117 [==============================] - 1s 7ms/step - loss: 0.1105 - mae: 0.2525 - val_loss: 0.1067 - val_mae: 0.2557
# Epoch 31/50
# 117/117 [==============================] - 1s 7ms/step - loss: 0.1065 - mae: 0.2486 - val_loss: 0.1067 - val_mae: 0.2568
# Epoch 32/50
# 117/117 [==============================] - 1s 8ms/step - loss: 0.1054 - mae: 0.2479 - val_loss: 0.1035 - val_mae: 0.2522
# Epoch 33/50
# 117/117 [==============================] - 1s 7ms/step - loss: 0.1033 - mae: 0.2449 - val_loss: 0.1042 - val_mae: 0.2529
# Epoch 34/50
# 117/117 [==============================] - 1s 8ms/step - loss: 0.1022 - mae: 0.2457 - val_loss: 0.1015 - val_mae: 0.2498
# Epoch 35/50
# 117/117 [==============================] - 1s 8ms/step - loss: 0.0996 - mae: 0.2411 - val_loss: 0.1030 - val_mae: 0.2531
# Epoch 36/50
# 117/117 [==============================] - 1s 7ms/step - loss: 0.0992 - mae: 0.2408 - val_loss: 0.1010 - val_mae: 0.2499
# Epoch 37/50
# 117/117 [==============================] - 1s 7ms/step - loss: 0.0962 - mae: 0.2372 - val_loss: 0.0961 - val_mae: 0.2422
# Epoch 38/50
# 117/117 [==============================] - 1s 7ms/step - loss: 0.0957 - mae: 0.2373 - val_loss: 0.0953 - val_mae: 0.2428
# Epoch 39/50
# 117/117 [==============================] - 1s 8ms/step - loss: 0.0940 - mae: 0.2346 - val_loss: 0.0927 - val_mae: 0.2387
# Epoch 40/50
# 117/117 [==============================] - 1s 8ms/step - loss: 0.0926 - mae: 0.2330 - val_loss: 0.0952 - val_mae: 0.2427
# Epoch 41/50
# 117/117 [==============================] - 1s 7ms/step - loss: 0.0913 - mae: 0.2318 - val_loss: 0.0944 - val_mae: 0.2402
# Epoch 42/50
# 117/117 [==============================] - 1s 7ms/step - loss: 0.0929 - mae: 0.2341 - val_loss: 0.0937 - val_mae: 0.2391
# Epoch 43/50
# 117/117 [==============================] - 1s 7ms/step - loss: 0.0921 - mae: 0.2312 - val_loss: 0.0920 - val_mae: 0.2358
# Epoch 44/50
# 117/117 [==============================] - 1s 7ms/step - loss: 0.0875 - mae: 0.2261 - val_loss: 0.0885 - val_mae: 0.2327
# Epoch 45/50
# 117/117 [==============================] - 1s 8ms/step - loss: 0.0866 - mae: 0.2250 - val_loss: 0.0915 - val_mae: 0.2354
# Epoch 46/50
# 117/117 [==============================] - 1s 8ms/step - loss: 0.0876 - mae: 0.2258 - val_loss: 0.0909 - val_mae: 0.2364
# Epoch 47/50
# 117/117 [==============================] - 1s 8ms/step - loss: 0.0860 - mae: 0.2241 - val_loss: 0.0878 - val_mae: 0.2310
# Epoch 48/50
# 117/117 [==============================] - 1s 8ms/step - loss: 0.0862 - mae: 0.2249 - val_loss: 0.0902 - val_mae: 0.2348
# Epoch 49/50
# 117/117 [==============================] - 1s 8ms/step - loss: 0.0852 - mae: 0.2230 - val_loss: 0.0853 - val_mae: 0.2289
# Epoch 50/50
# 117/117 [==============================] - 1s 8ms/step - loss: 0.0836 - mae: 0.2205 - val_loss: 0.0853 - val_mae: 0.2295

# %%
loss, mae = model.evaluate(val_X, val_y)
print(f"Mean Absolute Error: {mae}")
# Out:
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1160 - mae: 0.2163
# Mean Absolute Error: 0.21630370616912842

# %%
original_mae = np.expm1(mae)
print(original_mae)
# Out:
# 0.2414793666935405

# %%
y_pred_log = model.predict(val_X)
y_pred = np.expm1(y_pred_log)
y_true = np.expm1(val_y)

mae_original = mean_absolute_error(y_true, y_pred)
print(mae_original)
# Out:
# 49/49 [==============================] - 0s 2ms/step
# 1867108.6521949645
